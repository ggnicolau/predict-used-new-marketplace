# %%
# You can safely assume that `build_dataset` is correctly implemented
def build_dataset():
    data = [json.loads(x) for x in open("MLA_100k_checked_v3.jsonlines")]
    target = lambda x: x.get("condition")
    N = -10000
    X_train = data[:N]
    X_test = data[N:]
    y_train = [target(x) for x in X_train]
    y_test = [target(x) for x in X_test]
    for x in X_test:
        del x["condition"]
    return X_train, y_train, X_test, y_test

# %%
# You can safely assume that `build_dataset` is correctly implemented
def build_dataset():
    data = [json.loads(x) for x in open("MLA_100k_checked_v3.jsonlines")]
    target = lambda x: x.get("condition")
    N = -10000
    X_train = data[:N]
    X_test = data[N:]
    y_train = [target(x) for x in X_train]
    y_test = [target(x) for x in X_test]
    for x in X_test:
        del x["condition"]
    return X_train, y_train, X_test, y_test

# %%
data = [json.loads(x) for x in open("MLA_100k_checked_v3.jsonlines")]
target = lambda x: x.get("condition")
N = -10000
X_train = data[:N]
X_test = data[N:]
y_train = [target(x) for x in X_train]
y_test = [target(x) for x in X_test]
for x in X_test:
    del x["condition"]

# %%
X_train
# Out:
# [{'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'San Cristóbal', 'id': 'TUxBQlNBTjkwNTZa'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 80.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Acordar con el comprador', 'id': 'MLAWC', 'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 8208882349,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 80.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA6553902747',
#   'coverage_areas': [],
#   'category_id': 'MLA126406',
#   'descriptions': ["{'id': 'MLA4695330653-912855983'}"],
#   'last_updated': '2015-09-05T20:42:58.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/5386-MLA4695330653_052013-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/5386-MLA4695330653_052013-O.jpg',
#     'quality': '',
#     'id': '5386-MLA4695330653_052013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/5361-MLA4695330653_052013-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/5361-MLA4695330653_052013-O.jpg',
#     'quality': '',
#     'id': '5361-MLA4695330653_052013'}],
#   'id': 'MLA4695330653',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/5386-MLA4695330653_052013-I.jpg',
#   'title': 'Auriculares Samsung Originales Manos Libres Cable Usb Oferta',
#   'automatic_relist': False,
#   'date_created': '2015-09-05T20:42:53.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/5386-MLA4695330653_052013-I.jpg',
#   'stop_time': 1446669773000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1441485773000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA4695330653-auriculares-samsung-originales-manos-libres-cable-usb-oferta-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Buenos Aires', 'id': ''}},
#   'warranty': 'NUESTRA REPUTACION',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 2650.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 8141699488,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'silver',
#   'price': 2650.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': 'MLA7727150374',
#   'coverage_areas': [],
#   'category_id': 'MLA10267',
#   'descriptions': ["{'id': 'MLA7160447179-930764806'}"],
#   'last_updated': '2015-09-26T18:08:34.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '499x334',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/23223-MLA7160447179_022015-O.jpg',
#     'max_size': '951x637',
#     'url': 'http://mla-s1-p.mlstatic.com/23223-MLA7160447179_022015-O.jpg',
#     'quality': '',
#     'id': '23223-MLA7160447179_022015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/23273-MLA7160447179_022015-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s2-p.mlstatic.com/23273-MLA7160447179_022015-O.jpg',
#     'quality': '',
#     'id': '23273-MLA7160447179_022015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/23205-MLA7160447179_022015-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s1-p.mlstatic.com/23205-MLA7160447179_022015-O.jpg',
#     'quality': '',
#     'id': '23205-MLA7160447179_022015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/23289-MLA7160447179_022015-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s2-p.mlstatic.com/23289-MLA7160447179_022015-O.jpg',
#     'quality': '',
#     'id': '23289-MLA7160447179_022015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/23220-MLA7160447179_022015-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s1-p.mlstatic.com/23220-MLA7160447179_022015-O.jpg',
#     'quality': '',
#     'id': '23220-MLA7160447179_022015'},
#    {'size': '500x326',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/23201-MLA7160447179_022015-O.jpg',
#     'max_size': '924x603',
#     'url': 'http://mla-s1-p.mlstatic.com/23201-MLA7160447179_022015-O.jpg',
#     'quality': '',
#     'id': '23201-MLA7160447179_022015'}],
#   'id': 'MLA7160447179',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/23223-MLA7160447179_022015-I.jpg',
#   'title': 'Cuchillo Daga Acero Carbón Casco Yelmo Solingen Con Vaina',
#   'automatic_relist': False,
#   'date_created': '2015-09-26T18:08:30.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/23223-MLA7160447179_022015-I.jpg',
#   'stop_time': 1448474910000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443290910000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA7160447179-cuchillo-daga-acero-carbon-casco-yelmo-solingen-con-vaina-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Boedo', 'id': 'TUxBQkJPRTQ0OTRa'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 60.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Tarjeta de crédito', 'id': 'MLAOT', 'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 8386096505,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 60.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA6561247998',
#   'coverage_areas': [],
#   'category_id': 'MLA1227',
#   'descriptions': ["{'id': 'MLA7367189936-916478256'}"],
#   'last_updated': '2015-09-09T23:57:10.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/22076-MLA7367189936_012015-O.jpg',
#     'max_size': '900x1200',
#     'url': 'http://mla-s1-p.mlstatic.com/22076-MLA7367189936_012015-O.jpg',
#     'quality': '',
#     'id': '22076-MLA7367189936_012015'}],
#   'id': 'MLA7367189936',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/22076-MLA7367189936_012015-I.jpg',
#   'title': 'Antigua Revista Billiken, N° 1826, Año 1954',
#   'automatic_relist': False,
#   'date_created': '2015-09-09T23:57:07.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/22076-MLA7367189936_012015-I.jpg',
#   'stop_time': 1447027027000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1441843027000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA7367189936-antigua-revista-billiken-n-1826-ano-1954-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Floresta', 'id': 'TUxBQkZMTzg5MjFa'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 580.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Tarjeta de crédito', 'id': 'MLAOT', 'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 5377752182,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'silver',
#   'price': 580.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': None,
#   'coverage_areas': [],
#   'category_id': 'MLA86345',
#   'descriptions': ["{'id': 'MLA9191625553-932309698'}"],
#   'last_updated': '2015-10-05T16:03:50.306Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '441x423',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/183901-MLA9191625553_092015-O.jpg',
#     'max_size': '441x423',
#     'url': 'http://mla-s2-p.mlstatic.com/183901-MLA9191625553_092015-O.jpg',
#     'quality': '',
#     'id': '183901-MLA9191625553_092015'},
#    {'size': '500x372',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/632901-MLA9191625553_092015-O.jpg',
#     'max_size': '500x372',
#     'url': 'http://mla-s2-p.mlstatic.com/632901-MLA9191625553_092015-O.jpg',
#     'quality': '',
#     'id': '632901-MLA9191625553_092015'}],
#   'id': 'MLA9191625553',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/183901-MLA9191625553_092015-I.jpg',
#   'title': 'Alarma Guardtex Gx412 Seguridad Para El Automotor!!!',
#   'automatic_relist': False,
#   'date_created': '2015-09-28T18:47:56.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/183901-MLA9191625553_092015-I.jpg',
#   'stop_time': 1449191596000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443466076000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA9191625553-alarma-guardtex-gx412-seguridad-para-el-automotor-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Tres de febrero', 'id': 'TUxBQ1RSRTMxODE5NA'}},
#   'warranty': 'MI REPUTACION.',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 30.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Acordar con el comprador', 'id': 'MLAWC', 'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 2938071313,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 30.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA3133256685',
#   'coverage_areas': [],
#   'category_id': 'MLA41287',
#   'descriptions': ["{'id': 'MLA7787961817-902981678'}"],
#   'last_updated': '2015-08-28T13:37:41.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/13595-MLA7787961817_1713-O.jpg',
#     'max_size': '480x640',
#     'url': 'http://mla-s2-p.mlstatic.com/13595-MLA7787961817_1713-O.jpg',
#     'quality': '',
#     'id': '13595-MLA7787961817_1713'},
#    {'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/13596-MLA7787961817_1837-O.jpg',
#     'max_size': '480x640',
#     'url': 'http://mla-s1-p.mlstatic.com/13596-MLA7787961817_1837-O.jpg',
#     'quality': '',
#     'id': '13596-MLA7787961817_1837'}],
#   'id': 'MLA7787961817',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/13595-MLA7787961817_1713-I.jpg',
#   'title': 'Serenata - Jennifer Blake',
#   'automatic_relist': False,
#   'date_created': '2015-08-24T22:07:20.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/13595-MLA7787961817_1713-I.jpg',
#   'stop_time': 1445638040000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1440454040000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA7787961817-serenata-jennifer-blake-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Villa Adelina', 'id': ''}},
#   'warranty': 'Sí',
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 310.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Tarjeta de crédito', 'id': 'MLAOT', 'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 4086336590,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 310.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA5588379672',
#   'coverage_areas': [],
#   'category_id': 'MLA1429',
#   'descriptions': ["{'id': 'MLA6542680143-907239038'}"],
#   'last_updated': '2015-08-30T14:24:09.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '250x250',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/6207-MLA6542680143_3765-O.jpg',
#     'max_size': '250x250',
#     'url': 'http://mla-s2-p.mlstatic.com/6207-MLA6542680143_3765-O.jpg',
#     'quality': '',
#     'id': '6207-MLA6542680143_3765'}],
#   'id': 'MLA6542680143',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/6207-MLA6542680143_3765-I.jpg',
#   'title': 'Clavo De Olor(*1/2)  Grano Origen Turquia',
#   'automatic_relist': False,
#   'date_created': '2015-08-30T14:24:02.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/6207-MLA6542680143_3765-I.jpg',
#   'stop_time': 1446128641000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1440944641000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA6542680143-clavo-de-olor12-grano-origen-turquia-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Barracas', 'id': 'TUxBQkJBUjM0MDha'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 180.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [],
#   'seller_id': 9645655791,
#   'variations': [{'attribute_combinations': [{'value_id': '92012',
#       'name': 'Color Primario',
#       'value_name': 'Azul petróleo',
#       'id': '83000'},
#      {'value_id': '82034',
#       'name': 'Color Secundario',
#       'value_name': 'Amarillo',
#       'id': '73001'},
#      {'value_id': '141996',
#       'name': 'Talle',
#       'value_name': '8',
#       'id': '103000'}],
#     'seller_custom_field': None,
#     'picture_ids': ['472901-MLA20442937232_102015',
#      '509801-MLA20442939057_102015',
#      '650901-MLA20442940047_102015',
#      '373901-MLA20442951026_102015',
#      '422901-MLA20442950410_102015'],
#     'sold_quantity': 0,
#     'available_quantity': 1,
#     'id': 9742952789,
#     'price': 180}],
#   'site_id': 'MLA',
#   'listing_type_id': 'free',
#   'price': 180.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': None,
#   'coverage_areas': [],
#   'category_id': 'MLA352650',
#   'descriptions': ["{'id': 'MLA8224797916-939033580'}"],
#   'last_updated': '2015-10-06T22:32:46.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/472901-MLA8224797916_102015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/472901-MLA8224797916_102015-O.jpg',
#     'quality': '',
#     'id': '472901-MLA8224797916_102015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/509801-MLA8224797916_102015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/509801-MLA8224797916_102015-O.jpg',
#     'quality': '',
#     'id': '509801-MLA8224797916_102015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/650901-MLA8224797916_102015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/650901-MLA8224797916_102015-O.jpg',
#     'quality': '',
#     'id': '650901-MLA8224797916_102015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/373901-MLA8224797916_102015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/373901-MLA8224797916_102015-O.jpg',
#     'quality': '',
#     'id': '373901-MLA8224797916_102015'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/422901-MLA8224797916_102015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/422901-MLA8224797916_102015-O.jpg',
#     'quality': '',
#     'id': '422901-MLA8224797916_102015'}],
#   'id': 'MLA8224797916',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/472901-MLA8224797916_102015-I.jpg',
#   'title': 'Short Nike Fit Boca Juniors Talle S 7-8 Años',
#   'automatic_relist': False,
#   'date_created': '2015-10-06T22:32:41.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/472901-MLA8224797916_102015-I.jpg',
#   'stop_time': 1449354761000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1444170761000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA8224797916-short-nike-fit-boca-juniors-talle-s-7-8-anos-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Avellaneda/Capital Federal', 'id': ''}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 150.0,
#   'shipping': {'local_pick_up': False,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 4755818264,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'free',
#   'price': 150.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA8744215055',
#   'coverage_areas': [],
#   'category_id': 'MLA1227',
#   'descriptions': ["{'id': 'MLA1395917367-944499723'}"],
#   'last_updated': '2015-10-14T19:36:54.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9874-MLA1395917367_122013-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s2-p.mlstatic.com/9874-MLA1395917367_122013-O.jpg',
#     'quality': '',
#     'id': '9874-MLA1395917367_122013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/9824-MLA1395917367_122013-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s1-p.mlstatic.com/9824-MLA1395917367_122013-O.jpg',
#     'quality': '',
#     'id': '9824-MLA1395917367_122013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/9817-MLA1395917367_122013-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s1-p.mlstatic.com/9817-MLA1395917367_122013-O.jpg',
#     'quality': '',
#     'id': '9817-MLA1395917367_122013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9825-MLA1395917367_122013-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s2-p.mlstatic.com/9825-MLA1395917367_122013-O.jpg',
#     'quality': '',
#     'id': '9825-MLA1395917367_122013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/9809-MLA1395917367_122013-O.jpg',
#     'max_size': '1024x768',
#     'url': 'http://mla-s1-p.mlstatic.com/9809-MLA1395917367_122013-O.jpg',
#     'quality': '',
#     'id': '9809-MLA1395917367_122013'}],
#   'id': 'MLA1395917367',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/9874-MLA1395917367_122013-I.jpg',
#   'title': 'Plaza De Toros Iglesias Vistas Aereas De España 1965',
#   'automatic_relist': False,
#   'date_created': '2015-10-14T19:36:52.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9874-MLA1395917367_122013-I.jpg',
#   'stop_time': 1450035412000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1444851412000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA1395917367-plaza-de-toros-iglesias-vistas-aereas-de-espana-1965-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Capital Federal', 'id': ''}},
#   'warranty': '1 Ano',
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 2352.0,
#   'shipping': {'local_pick_up': True,
#    'free_methods': [{'rule': {'value': None, 'free_mode': 'country'},
#      'id': 73328}],
#    'tags': [],
#    'free_shipping': True,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Tarjeta de crédito',
#     'id': 'MLAOT',
#     'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 1809776792,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'gold_special',
#   'price': 2352.0,
#   'attributes': [{'value_id': '',
#     'attribute_group_id': 'DFLT',
#     'name': 'Número de pieza',
#     'value_name': '37123',
#     'attribute_group_name': 'Otros',
#     'id': 'PART_NUMBER'}],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': None,
#   'coverage_areas': [],
#   'category_id': 'MLA352293',
#   'descriptions': ["{'id': 'MLA6054779321-934355208'}"],
#   'last_updated': '2015-10-02T00:01:26.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/797901-MLA6054779321_092015-O.jpg',
#     'max_size': '800x800',
#     'url': 'http://mla-s1-p.mlstatic.com/797901-MLA6054779321_092015-O.jpg',
#     'quality': '',
#     'id': '797901-MLA6054779321_092015'},
#    {'size': '500x299',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/475901-MLA6054779321_092015-O.jpg',
#     'max_size': '934x560',
#     'url': 'http://mla-s1-p.mlstatic.com/475901-MLA6054779321_092015-O.jpg',
#     'quality': '',
#     'id': '475901-MLA6054779321_092015'},
#    {'size': '500x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/124901-MLA6054779321_092015-O.jpg',
#     'max_size': '650x650',
#     'url': 'http://mla-s2-p.mlstatic.com/124901-MLA6054779321_092015-O.jpg',
#     'quality': '',
#     'id': '124901-MLA6054779321_092015'}],
#   'id': 'MLA6054779321',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/797901-MLA6054779321_092015-I.jpg',
#   'title': 'Kit X2 Amortiguador Trasero Monroe Chrysler Caravan 01',
#   'automatic_relist': True,
#   'date_created': '2015-09-30T21:50:22.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/797901-MLA6054779321_092015-I.jpg',
#   'stop_time': 1448833822000,
#   'status': 'paused',
#   'video_id': 'QQNfOicE_o8',
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 10,
#   'start_time': 1443649822000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA6054779321-kit-x2-amortiguador-trasero-monroe-chrysler-caravan-01-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 10},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'monte grande', 'id': ''}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 120.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Efectivo',
#     'id': 'MLAMO',
#     'type': 'G'}],
#   'seller_id': 2852894385,
#   'variations': [{'attribute_combinations': [{'value_id': '92021',
#       'name': 'Color Primario',
#       'value_name': 'Fucsia',
#       'id': '83000'},
#      {'value_id': '141992',
#       'name': 'Talle',
#       'value_name': '1',
#       'id': '103000'}],
#     'seller_custom_field': None,
#     'picture_ids': ['22802-MLA20237759642_022015',
#      '22826-MLA20237759652_022015'],
#     'sold_quantity': 1,
#     'available_quantity': 1,
#     'id': 9720380234,
#     'price': 120}],
#   'site_id': 'MLA',
#   'listing_type_id': 'silver',
#   'price': 120.0,
#   'attributes': [{'value_id': 'female',
#     'attribute_group_id': 'DFLT',
#     'name': 'Género',
#     'value_name': 'Mujer',
#     'attribute_group_name': 'Otros',
#     'id': 'GENDER'},
#    {'value_id': 'Season-Spring-Summer',
#     'attribute_group_id': 'FIND',
#     'name': 'Season',
#     'value_name': 'Spring-Summer',
#     'attribute_group_name': 'Ficha técnica',
#     'id': 'Season'}],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': 'MLA4442923846',
#   'coverage_areas': [],
#   'category_id': 'MLA121665',
#   'descriptions': ["{'id': 'MLA3801903502-936622752'}"],
#   'last_updated': '2015-10-08T20:02:01.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/22802-MLA3801903502_022015-O.jpg',
#     'max_size': '480x640',
#     'url': 'http://mla-s1-p.mlstatic.com/22802-MLA3801903502_022015-O.jpg',
#     'quality': '',
#     'id': '22802-MLA3801903502_022015'},
#    {'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/22826-MLA3801903502_022015-O.jpg',
#     'max_size': '480x640',
#     'url': 'http://mla-s2-p.mlstatic.com/22826-MLA3801903502_022015-O.jpg',
#     'quality': '',
#     'id': '22826-MLA3801903502_022015'}],
#   'id': 'MLA3801903502',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/22802-MLA3801903502_022015-I.jpg',
#   'title': 'Bonitas Mallas Color Fuccia Talle 1 Y 2',
#   'automatic_relist': False,
#   'date_created': '2015-10-03T23:11:30.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/22802-MLA3801903502_022015-I.jpg',
#   'stop_time': 1449097889000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 2,
#   'start_time': 1443913889000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA3801903502-bonitas-mallas-color-fuccia-talle-1-y-2-_JM',
#   'sold_quantity': 1,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Cañuelas', 'id': 'TUxBQ0NBTjk4NTM'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 50.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Efectivo',
#     'id': 'MLAMO',
#     'type': 'G'}],
#   'seller_id': 8919876655,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 50.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA3677718570',
#   'coverage_areas': [],
#   'category_id': 'MLA5375',
#   'descriptions': ["{'id': 'MLA3458937254-896308868'}"],
#   'last_updated': '2015-09-15T00:09:15.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x316',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/14032-MLA3458937254_042014-O.jpg',
#     'max_size': '650x412',
#     'url': 'http://mla-s2-p.mlstatic.com/14032-MLA3458937254_042014-O.jpg',
#     'quality': '',
#     'id': '14032-MLA3458937254_042014'},
#    {'size': '500x316',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/14036-MLA3458937254_042014-O.jpg',
#     'max_size': '650x412',
#     'url': 'http://mla-s1-p.mlstatic.com/14036-MLA3458937254_042014-O.jpg',
#     'quality': '',
#     'id': '14036-MLA3458937254_042014'},
#    {'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/14068-MLA3458937254_042014-O.jpg',
#     'max_size': '720x960',
#     'url': 'http://mla-s2-p.mlstatic.com/14068-MLA3458937254_042014-O.jpg',
#     'quality': '',
#     'id': '14068-MLA3458937254_042014'}],
#   'id': 'MLA3458937254',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/14032-MLA3458937254_042014-I.jpg',
#   'title': 'Analisis Clinicos Carlos De La Torre Cañuelas',
#   'automatic_relist': False,
#   'date_created': '2015-08-16T20:52:12.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/14032-MLA3458937254_042014-I.jpg',
#   'stop_time': 1444942332000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 100,
#   'start_time': 1439758332000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA3458937254-analisis-clinicos-carlos-de-la-torre-canuelas-_JM',
#   'sold_quantity': 1,
#   'available_quantity': 99},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Hurlingham', 'id': 'TUxBQ0hVUmxpbmdo'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 9500.0,
#   'shipping': {'local_pick_up': False,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [],
#   'seller_id': 6289922614,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'free',
#   'price': 9500.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA4007511794',
#   'coverage_areas': [],
#   'category_id': 'MLA348577',
#   'descriptions': ["{'id': 'MLA2886883946-933988500'}"],
#   'last_updated': '2015-10-04T19:14:33.142Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/435501-MLA2886883946_072015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/435501-MLA2886883946_072015-O.jpg',
#     'quality': '',
#     'id': '435501-MLA2886883946_072015'},
#    {'size': '500x280',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/623501-MLA2886883946_072015-O.jpg',
#     'max_size': '1200x674',
#     'url': 'http://mla-s2-p.mlstatic.com/623501-MLA2886883946_072015-O.jpg',
#     'quality': '',
#     'id': '623501-MLA2886883946_072015'},
#    {'size': '500x333',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/493501-MLA2886883946_072015-O.jpg',
#     'max_size': '1200x801',
#     'url': 'http://mla-s1-p.mlstatic.com/493501-MLA2886883946_072015-O.jpg',
#     'quality': '',
#     'id': '493501-MLA2886883946_072015'},
#    {'size': '500x368',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/675401-MLA2886883946_072015-O.jpg',
#     'max_size': '1200x884',
#     'url': 'http://mla-s2-p.mlstatic.com/675401-MLA2886883946_072015-O.jpg',
#     'quality': '',
#     'id': '675401-MLA2886883946_072015'}],
#   'id': 'MLA2886883946',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/435501-MLA2886883946_072015-I.jpg',
#   'title': 'Xperia Z2 16gb Nuevo + Garantia Con Banda Lte Argentina.',
#   'automatic_relist': False,
#   'date_created': '2015-09-30T15:05:21.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/435501-MLA2886883946_072015-I.jpg',
#   'stop_time': 1448809520000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443625520000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA2886883946-xperia-z2-16gb-nuevo-garantia-con-banda-lte-argentina-_JM',
#   'sold_quantity': 1,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'caba', 'id': ''}},
#   'warranty': 'VACIOS sin utilizar',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 69.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'custom',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 1250086998,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'free',
#   'price': 69.0,
#   'attributes': [{'value_id': '',
#     'attribute_group_id': 'DFLT',
#     'name': 'Número pieza',
#     'value_name': '2',
#     'attribute_group_name': 'Otros',
#     'id': 'MLA-PART_NUMBER'}],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA5519897707',
#   'coverage_areas': [],
#   'category_id': 'MLA375042',
#   'descriptions': ["{'id': 'MLA7263512597-931979681'}"],
#   'last_updated': '2015-09-28T13:31:42.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x355',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/19922-MLA7263512597_102014-O.jpg',
#     'max_size': '703x500',
#     'url': 'http://mla-s2-p.mlstatic.com/19922-MLA7263512597_102014-O.jpg',
#     'quality': '',
#     'id': '19922-MLA7263512597_102014'}],
#   'id': 'MLA7263512597',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/19922-MLA7263512597_102014-I.jpg',
#   'title': '2 Bidones Para Nafta Y Agua 10 Litros',
#   'automatic_relist': False,
#   'date_created': '2015-09-28T13:31:41.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/19922-MLA7263512597_102014-I.jpg',
#   'stop_time': 1448631101000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443447101000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA7263512597-2-bidones-para-nafta-y-agua-10-litros-_JM',
#   'sold_quantity': 1,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Wilde', 'id': 'TUxBV2lsZGU'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 450.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Tarjeta de crédito', 'id': 'MLAOT', 'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 8795257316,
#   'variations': [{'attribute_combinations': [{'value_id': '92000',
#       'name': 'Color Primario',
#       'value_name': 'Marrón',
#       'id': '83000'},
#      {'value_id': '101995',
#       'name': 'Talle',
#       'value_name': 'M',
#       'id': '93000'}],
#     'seller_custom_field': None,
#     'picture_ids': ['908601-MLA20391431364_082015',
#      '817701-MLA20391432183_082015',
#      '712701-MLA20391431814_082015'],
#     'sold_quantity': 0,
#     'available_quantity': 1,
#     'id': 9338152892,
#     'price': 450}],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 450.0,
#   'attributes': [{'value_id': 'female',
#     'attribute_group_id': 'DFLT',
#     'name': 'Género',
#     'value_name': 'Mujer',
#     'attribute_group_name': 'Otros',
#     'id': 'GENDER'},
#    {'value_id': 'Season-Spring-Summer',
#     'attribute_group_id': 'FIND',
#     'name': 'Season',
#     'value_name': 'Spring-Summer',
#     'attribute_group_name': 'Ficha técnica',
#     'id': 'Season'}],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': None,
#   'coverage_areas': [],
#   'category_id': 'MLA119326',
#   'descriptions': ["{'id': 'MLA7430243162-901775303'}"],
#   'last_updated': '2015-09-30T16:05:56.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '281x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/908601-MLA7430243162_082015-O.jpg',
#     'max_size': '675x1200',
#     'url': 'http://mla-s2-p.mlstatic.com/908601-MLA7430243162_082015-O.jpg',
#     'quality': '',
#     'id': '908601-MLA7430243162_082015'},
#    {'size': '281x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/817701-MLA7430243162_082015-O.jpg',
#     'max_size': '675x1200',
#     'url': 'http://mla-s2-p.mlstatic.com/817701-MLA7430243162_082015-O.jpg',
#     'quality': '',
#     'id': '817701-MLA7430243162_082015'},
#    {'size': '281x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/712701-MLA7430243162_082015-O.jpg',
#     'max_size': '675x1200',
#     'url': 'http://mla-s2-p.mlstatic.com/712701-MLA7430243162_082015-O.jpg',
#     'quality': '',
#     'id': '712701-MLA7430243162_082015'}],
#   'id': 'MLA7430243162',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/908601-MLA7430243162_082015-I.jpg',
#   'title': 'Remera Importada',
#   'automatic_relist': False,
#   'date_created': '2015-08-23T15:49:53.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/908601-MLA7430243162_082015-I.jpg',
#   'stop_time': 1445528993000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1440344993000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA7430243162-remera-importada-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Santa Fe', 'id': 'AR-S'},
#    'city': {'name': 'Rosario', 'id': 'TUxBQ1JPUzg1Yjg3'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 155.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [],
#   'seller_id': 8945086454,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 155.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA7199231813',
#   'coverage_areas': [],
#   'category_id': 'MLA40489',
#   'descriptions': ["{'id': 'MLA6352077222-936567500'}"],
#   'last_updated': '2015-10-03T21:48:08.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9054-MLA6352077222_112013-O.jpg',
#     'max_size': '768x1024',
#     'url': 'http://mla-s2-p.mlstatic.com/9054-MLA6352077222_112013-O.jpg',
#     'quality': '',
#     'id': '9054-MLA6352077222_112013'}],
#   'id': 'MLA6352077222',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/9054-MLA6352077222_112013-I.jpg',
#   'title': 'Valdelomar O La Belle Epoque ( 1ªed S/uso)   Luis A. Sanchez',
#   'automatic_relist': False,
#   'date_created': '2015-10-03T21:48:05.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9054-MLA6352077222_112013-I.jpg',
#   'stop_time': 1449092885000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443908885000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA6352077222-valdelomar-o-la-belle-epoque-1ed-suso-luis-a-sanchez-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Hurlingham', 'id': 'TUxBQ0hVUmxpbmdo'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 100.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Acordar con el comprador',
#     'id': 'MLAWC',
#     'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 8282616551,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 100.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA7709742034',
#   'coverage_areas': [],
#   'category_id': 'MLA34276',
#   'descriptions': ["{'id': 'MLA5070808455-922902919'}"],
#   'last_updated': '2015-09-17T13:43:38.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x331',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/15074-MLA5070808455_052014-O.jpg',
#     'max_size': '1200x795',
#     'url': 'http://mla-s2-p.mlstatic.com/15074-MLA5070808455_052014-O.jpg',
#     'quality': '',
#     'id': '15074-MLA5070808455_052014'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/13691-MLA5070808455_092012-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/13691-MLA5070808455_092012-O.jpg',
#     'quality': '',
#     'id': '13691-MLA5070808455_092012'},
#    {'size': '500x331',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/13273-MLA5070808455_042014-O.jpg',
#     'max_size': '1200x795',
#     'url': 'http://mla-s1-p.mlstatic.com/13273-MLA5070808455_042014-O.jpg',
#     'quality': '',
#     'id': '13273-MLA5070808455_042014'},
#    {'size': '500x331',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/15067-MLA5070808455_052014-O.jpg',
#     'max_size': '1200x795',
#     'url': 'http://mla-s1-p.mlstatic.com/15067-MLA5070808455_052014-O.jpg',
#     'quality': '',
#     'id': '15067-MLA5070808455_052014'},
#    {'size': '500x331',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/13230-MLA5070808455_042014-O.jpg',
#     'max_size': '1200x795',
#     'url': 'http://mla-s2-p.mlstatic.com/13230-MLA5070808455_042014-O.jpg',
#     'quality': '',
#     'id': '13230-MLA5070808455_042014'}],
#   'id': 'MLA5070808455',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/15074-MLA5070808455_052014-I.jpg',
#   'title': 'Alzada Porta Chupetines Y Golosinas',
#   'automatic_relist': False,
#   'date_created': '2015-09-17T13:43:37.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/15074-MLA5070808455_052014-I.jpg',
#   'stop_time': 1447681417000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1442497417000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA5070808455-alzada-porta-chupetines-y-golosinas-_JM',
#   'sold_quantity': 4,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Buenos Aires', 'id': 'AR-B'},
#    'city': {'name': 'Ramos Mejia', 'id': ''}},
#   'warranty': 'Se ve en el dia de la compra',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 30.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Efectivo',
#     'id': 'MLAMO',
#     'type': 'G'}],
#   'seller_id': 5011914197,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 30.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA9963362573',
#   'coverage_areas': [],
#   'category_id': 'MLA8290',
#   'descriptions': ["{'id': 'MLA2357851799-923389664'}"],
#   'last_updated': '2015-09-18T00:45:51.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/23100-MLA2357851799_022015-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s1-p.mlstatic.com/23100-MLA2357851799_022015-O.jpg',
#     'quality': '',
#     'id': '23100-MLA2357851799_022015'},
#    {'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/23097-MLA2357851799_022015-O.jpg',
#     'max_size': '900x1200',
#     'url': 'http://mla-s2-p.mlstatic.com/23097-MLA2357851799_022015-O.jpg',
#     'quality': '',
#     'id': '23097-MLA2357851799_022015'},
#    {'size': '375x500',
# ...
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA6344351455',
#   'coverage_areas': [],
#   'category_id': 'MLA41278',
#   'descriptions': ["{'id': 'MLA9137457707-897041701'}"],
#   'last_updated': '2015-08-17T19:16:01.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '375x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/179101-MLA9137457707_042015-O.jpg',
#     'max_size': '900x1200',
#     'url': 'http://mla-s2-p.mlstatic.com/179101-MLA9137457707_042015-O.jpg',
#     'quality': '',
#     'id': '179101-MLA9137457707_042015'}],
#   'id': 'MLA9137457707',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/179101-MLA9137457707_042015-I.jpg',
#   'title': 'Hector Rivas; Lo Bueno Y O Malo',
#   'automatic_relist': False,
#   'date_created': '2015-08-17T19:14:53.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/179101-MLA9137457707_042015-I.jpg',
#   'stop_time': 1445022892000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1439838892000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA9137457707-hector-rivas-lo-bueno-y-o-malo-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'buenos aires', 'id': ''}},
#   'warranty': '6 meses',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 250.0,
#   'shipping': {'local_pick_up': False,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [],
#   'seller_id': 4731443734,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 250.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA5052242744',
#   'coverage_areas': [],
#   'category_id': 'MLA9309',
#   'descriptions': ["{'id': 'MLA3366377753-931217347'}"],
#   'last_updated': '2015-09-27T11:10:45.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9181-MLA3366377753_112013-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/9181-MLA3366377753_112013-O.jpg',
#     'quality': '',
#     'id': '9181-MLA3366377753_112013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9171-MLA3366377753_112013-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/9171-MLA3366377753_112013-O.jpg',
#     'quality': '',
#     'id': '9171-MLA3366377753_112013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9171-MLA3366377753_112013-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/9171-MLA3366377753_112013-O.jpg',
#     'quality': '',
#     'id': '9171-MLA3366377753_112013'},
#    {'size': '500x375',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9129-MLA3366377753_112013-O.jpg',
#     'max_size': '1200x900',
#     'url': 'http://mla-s2-p.mlstatic.com/9129-MLA3366377753_112013-O.jpg',
#     'quality': '',
#     'id': '9129-MLA3366377753_112013'}],
#   'id': 'MLA3366377753',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/9181-MLA3366377753_112013-I.jpg',
#   'title': 'Reloj Cetikon',
#   'automatic_relist': False,
#   'date_created': '2015-09-27T11:10:43.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/9181-MLA3366377753_112013-I.jpg',
#   'stop_time': 1448536243000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443352243000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA3366377753-reloj-cetikon-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'CABA', 'id': ''}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 4970.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Tarjeta de crédito', 'id': 'MLAOT', 'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 7704929703,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 4970.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': None,
#   'coverage_areas': [],
#   'category_id': 'MLA1914',
#   'descriptions': ["{'id': 'MLA2798219509-927283817'}"],
#   'last_updated': '2015-10-05T18:31:10.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '200x200',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/691901-MLA2798219509_092015-O.jpg',
#     'max_size': '200x200',
#     'url': 'http://mla-s1-p.mlstatic.com/691901-MLA2798219509_092015-O.jpg',
#     'quality': '',
#     'id': '691901-MLA2798219509_092015'}],
#   'id': 'MLA2798219509',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/691901-MLA2798219509_092015-I.jpg',
#   'title': 'Tiffen 4 X 4  85 Linear Polarizer Filter',
#   'automatic_relist': False,
#   'date_created': '2015-09-22T19:01:55.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/691901-MLA2798219509_092015-I.jpg',
#   'stop_time': 1448132515000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 10,
#   'start_time': 1442948515000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA2798219509-tiffen-4-x-4-85-linear-polarizer-filter-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 10},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Congreso', 'id': ''}},
#   'warranty': 'Sí',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 80.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Tarjeta de crédito',
#     'id': 'MLAOT',
#     'type': 'N'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 2340670007,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'free',
#   'price': 80.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA5850632582',
#   'coverage_areas': [],
#   'category_id': 'MLA3530',
#   'descriptions': ["{'id': 'MLA7783092732-924123113'}"],
#   'last_updated': '2015-09-18T20:35:54.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '334x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/826301-MLA7783092732_052015-O.jpg',
#     'max_size': '802x1200',
#     'url': 'http://mla-s1-p.mlstatic.com/826301-MLA7783092732_052015-O.jpg',
#     'quality': '',
#     'id': '826301-MLA7783092732_052015'}],
#   'id': 'MLA7783092732',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s1-p.mlstatic.com/826301-MLA7783092732_052015-I.jpg',
#   'title': 'La Peste- Camus Albert',
#   'automatic_relist': False,
#   'date_created': '2015-09-18T20:35:53.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/826301-MLA7783092732_052015-I.jpg',
#   'stop_time': 1447792552000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1442608552000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA7783092732-la-peste-camus-albert-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Belgrano', 'id': 'TUxBQkJFTDcyNTJa'}},
#   'warranty': 'Sí',
#   'sub_status': [],
#   'condition': 'used',
#   'deal_ids': [],
#   'base_price': 25.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Efectivo',
#     'id': 'MLAMO',
#     'type': 'G'}],
#   'seller_id': 3135396608,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'free',
#   'price': 25.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA2250982104',
#   'coverage_areas': [],
#   'category_id': 'MLA40608',
#   'descriptions': ["{'id': 'MLA9593980656-936428136'}"],
#   'last_updated': '2015-10-03T18:01:07.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '325x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/4137-MLA9593980656_2832-O.jpg',
#     'max_size': '568x872',
#     'url': 'http://mla-s2-p.mlstatic.com/4137-MLA9593980656_2832-O.jpg',
#     'quality': '',
#     'id': '4137-MLA9593980656_2832'},
#    {'size': '341x500',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/4137-MLA9593980656_9716-O.jpg',
#     'max_size': '525x768',
#     'url': 'http://mla-s2-p.mlstatic.com/4137-MLA9593980656_9716-O.jpg',
#     'quality': '',
#     'id': '4137-MLA9593980656_9716'}],
#   'id': 'MLA9593980656',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/4137-MLA9593980656_2832-I.jpg',
#   'title': 'Carl Sternheim - Napoleon. Libro En Aleman',
#   'automatic_relist': False,
#   'date_created': '2015-10-03T18:01:06.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/4137-MLA9593980656_2832-I.jpg',
#   'stop_time': 1449079266000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443895266000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA9593980656-carl-sternheim-napoleon-libro-en-aleman-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'Palermo', 'id': 'TUxBQlBBTDI1MTVa'}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 77.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'me2',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Efectivo',
#     'id': 'MLAMO',
#     'type': 'G'}],
#   'seller_id': 5248662274,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 77.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': [],
#   'listing_source': '',
#   'parent_item_id': None,
#   'coverage_areas': [],
#   'category_id': 'MLA1227',
#   'descriptions': ["{'id': 'MLA5480994367-937337530'}"],
#   'last_updated': '2015-10-05T02:52:24.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '327x154',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/297901-MLA5480994367_102015-O.jpg',
#     'max_size': '327x154',
#     'url': 'http://mla-s2-p.mlstatic.com/297901-MLA5480994367_102015-O.jpg',
#     'quality': '',
#     'id': '297901-MLA5480994367_102015'}],
#   'id': 'MLA5480994367',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/297901-MLA5480994367_102015-I.jpg',
#   'title': 'Mandalas-y La Plenitud - Mandalas -nuevo- #de12',
#   'automatic_relist': False,
#   'date_created': '2015-10-05T02:52:23.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/297901-MLA5480994367_102015-I.jpg',
#   'stop_time': 1449197541000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 3,
#   'start_time': 1444013541000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA5480994367-mandalas-y-la-plenitud-mandalas-nuevo-de12-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 3},
#  {'seller_address': {'country': {'name': 'Argentina', 'id': 'AR'},
#    'state': {'name': 'Capital Federal', 'id': 'AR-C'},
#    'city': {'name': 'MICROCENTRO', 'id': ''}},
#   'warranty': None,
#   'sub_status': [],
#   'condition': 'new',
#   'deal_ids': [],
#   'base_price': 3570.0,
#   'shipping': {'local_pick_up': True,
#    'methods': [],
#    'tags': [],
#    'free_shipping': False,
#    'mode': 'not_specified',
#    'dimensions': None},
#   'non_mercado_pago_payment_methods': [{'description': 'Transferencia bancaria',
#     'id': 'MLATB',
#     'type': 'G'},
#    {'description': 'Acordar con el comprador', 'id': 'MLAWC', 'type': 'G'},
#    {'description': 'Efectivo', 'id': 'MLAMO', 'type': 'G'}],
#   'seller_id': 3513735564,
#   'variations': [],
#   'site_id': 'MLA',
#   'listing_type_id': 'bronze',
#   'price': 3570.0,
#   'attributes': [],
#   'buying_mode': 'buy_it_now',
#   'tags': ['dragged_bids_and_visits'],
#   'listing_source': '',
#   'parent_item_id': 'MLA1524667348',
#   'coverage_areas': [],
#   'category_id': 'MLA7239',
#   'descriptions': ["{'id': 'MLA4607921718-930783222'}"],
#   'last_updated': '2015-09-26T18:48:03.000Z',
#   'international_delivery_mode': 'none',
#   'pictures': [{'size': '200x200',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/13604-MLA4607921718_092012-O.jpg',
#     'max_size': '200x200',
#     'url': 'http://mla-s2-p.mlstatic.com/13604-MLA4607921718_092012-O.jpg',
#     'quality': '',
#     'id': '13604-MLA4607921718_092012'},
#    {'size': '186x139',
#     'secure_url': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/13605-MLA4607921718_092012-O.jpg',
#     'max_size': '186x139',
#     'url': 'http://mla-s2-p.mlstatic.com/13605-MLA4607921718_092012-O.jpg',
#     'quality': '',
#     'id': '13605-MLA4607921718_092012'},
#    {'size': '158x45',
#     'secure_url': 'https://a248.e.akamai.net/mla-s1-p.mlstatic.com/13687-MLA4607921718_092012-O.jpg',
#     'max_size': '158x45',
#     'url': 'http://mla-s1-p.mlstatic.com/13687-MLA4607921718_092012-O.jpg',
#     'quality': '',
#     'id': '13687-MLA4607921718_092012'}],
#   'id': 'MLA4607921718',
#   'official_store_id': None,
#   'differential_pricing': None,
#   'accepts_mercadopago': True,
#   'original_price': None,
#   'currency_id': 'ARS',
#   'thumbnail': 'http://mla-s2-p.mlstatic.com/13604-MLA4607921718_092012-I.jpg',
#   'title': 'Toner Xerox P/impr.4510n Negro Alto Rend. Orig.  113r00712',
#   'automatic_relist': False,
#   'date_created': '2015-09-26T18:48:02.000Z',
#   'secure_thumbnail': 'https://a248.e.akamai.net/mla-s2-p.mlstatic.com/13604-MLA4607921718_092012-I.jpg',
#   'stop_time': 1448477281000,
#   'status': 'active',
#   'video_id': None,
#   'catalog_product_id': None,
#   'subtitle': None,
#   'initial_quantity': 1,
#   'start_time': 1443293281000,
#   'permalink': 'http://articulo.mercadolibre.com.ar/MLA4607921718-toner-xerox-pimpr4510n-negro-alto-rend-orig-113r00712-_JM',
#   'sold_quantity': 0,
#   'available_quantity': 1},
#  ...]
